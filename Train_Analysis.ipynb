# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('C:\\Users\\Kiran\\Downloads\\train.csv',
                 encoding='unicode_escape')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
pd.isnull(df)

# %%
pd.isnull(df).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.shape
# Out:
# (891, 12)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (183, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   183.000000  183.000000  183.000000  183.000000  183.000000
# mean    455.366120    0.672131    1.191257   35.661202    0.464481
# std     247.052476    0.470725    0.515187   15.654054    0.644159
# min       2.000000    0.000000    1.000000    0.000000    0.000000
# 25%     263.500000    0.000000    1.000000   24.000000    0.000000
# 50%     457.000000    1.000000    1.000000   36.000000    0.000000
# 75%     676.000000    1.000000    1.000000   47.500000    1.000000
# max     890.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  183.000000  183.000000
# mean     0.475410   78.682469
# std      0.754617   76.347843
# min      0.000000    0.000000
# 25%      0.000000   29.700000
# 50%      0.000000   57.000000
# 75%      1.000000   90.000000
# max      4.000000  512.329200

# %%
df[['Pclass' ,'Parch' , 'Fare']].describe()
# Out:
#            Pclass       Parch        Fare
# count  183.000000  183.000000  183.000000
# mean     1.191257    0.475410   78.682469
# std      0.515187    0.754617   76.347843
# min      1.000000    0.000000    0.000000
# 25%      1.000000    0.000000   29.700000
# 50%      1.000000    0.000000   57.000000
# 75%      1.000000    1.000000   90.000000
# max      3.000000    4.000000  512.329200

# %%
df['Age'] = df['Age'].astype('int')

# %%
df['Age'].dtypes
# Out:
# dtype('int64')

# %%
df['Sex'].value_counts()
# Out:
# Sex
# male      95
# female    88
# Name: count, dtype: int64

# %%
sns.pairplot(df, kind='reg', diag_kind='kde')

# %%
data=np.random.randint(low = 1,high = 100,size = (10,10))
print(data)
# Out:
# [[52 85 53 63 36 55  4  2 47 33]
#  [ 1 48 58 73  4 24 97 24 73 44]
#  [ 1 67 92  9 58 36 20 46 48 25]
#  [68  4 86 82 49 60 81 90 51  8]
#  [25 66 51 27 43 13 53 79 33 78]
#  [77 53 45 40 20 81 50 22 24 67]
#  [82 45 63 54 99 52 15 65 73 19]
#  [66 85 73 33 23 50 33 88 58 45]
#  [79 58 98 76 69 87 62  9 62 28]
#  [15 97 61 83 17  8 89  7 99 66]]

# %%
sns.heatmap(data = data, linecolor='red' , linewidth = '2')
# Out:
# <Axes: >

# %%
sns.heatmap(data = data ,annot = True)
# Out:
# <Axes: >

# %%
sns.heatmap(data = data ,xticklabels = False , yticklabels = False , annot = True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x = X , y= Y)
X=df.Survived
Y=df.Pclass
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('Scatter Plot')
plt.show()

# %%
data =df.Parch
plt.hist(data , bins= 4 , color = 'yellow' , edgecolor = 'black') 
plt.title('Histogram Plot')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
group1 = [10,15,20,15,25]
group2 = [30,16,10,25,29]
group3 = [5,15,20,25,30]

plt.boxplot([group1 , group2, group3] , tick_labels=['Group 1','Group 2','Group 3'])
plt.title('BoxPlot')
plt.xlabel('Groups')
plt.ylabel('Values')
plt.show()
